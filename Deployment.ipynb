# %%
import requests

# NOTE: you must manually set API_KEY below using information retrieved from your IBM Cloud account (https://dataplatform.cloud.ibm.com/docs/content/wsj/analyze-data/ml-authentication.html)
API_KEY = "DK22b0rwz6_gN1MM62jTyB7V_ARliBPYkMqsJWp1w2C9"
token_response = requests.post('https://iam.cloud.ibm.com/identity/token', data={"apikey": API_KEY, "grant_type": 'urn:ibm:params:oauth:grant-type:apikey'})
mltoken = token_response.json()["access_token"]

header = {'Content-Type': 'application/json', 'Authorization': 'Bearer ' + mltoken}

# Fungsi dummy untuk mengubah teks menjadi embedding
def text_to_embedding(text):
    # Dummy embedding, hanya untuk ilustrasi, seharusnya Anda menggunakan model pre-trained untuk mendapatkan embedding yang benar
    return [0.0] * 300  # Mengembalikan vektor dengan panjang 300

# Teks yang akan diubah menjadi embedding
texts = [
    "The President of Indonesia met with Barack Obama to discuss the sale and purchase of Antarctic islands.",
    "The next US president will surely push the next UK prime minister to continue to play a leadership role – and perhaps an even bigger one – in NATO and on Ukraine."
    "Eight Israeli soldiers killed in Gaza in one of the deadliest single incidents for Israeli forces since October 7"
]

# Mengubah teks menjadi embedding
embeddings = [text_to_embedding(text) for text in texts]

payload_scoring = {
    "input_data": [
        {
            "fields": ["embedding"],
            "values": embeddings
        }
    ]
}

response_scoring = requests.post('https://private.us-south.ml.cloud.ibm.com/ml/v4/deployments/87698110-cb7e-40b1-824a-b0e08df8165c/predictions?version=2021-05-01', json=payload_scoring,
 headers={'Authorization': 'Bearer ' + mltoken})
print("Scoring response")
response_json = response_scoring.json()

# Asumsi struktur respons JSON dari model Anda
predictions = response_json.get("predictions", [])[0].get("values", [])

# Memeriksa dan mencetak hasil
for prediction in predictions:
    if prediction[0] == "True":
        print("Yes, this News is True")
    else:
        print("No, this News is Fake")
# Out:
# Scoring response
# No, this News is Fake
# No, this News is Fake
